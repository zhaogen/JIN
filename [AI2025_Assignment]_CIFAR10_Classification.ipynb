# %% [markdown]
# <a href="https://colab.research.google.com/github/zhaogen/JIN/blob/main/%5BAI2025_Assignment%5D_CIFAR10_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CIFAR10 Classification

# %% [markdown]
# ## Import Packages

# %%
import sys
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ### Data Preparation
# Use CIFAR10 handwriting dataset

# %%
cifar10 = tf.keras.datasets.cifar10

# %% [markdown]
# Prepare data for training

# %%
# train / test split
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# minmax normalization
x_train, x_test = x_train / 255.0, x_test / 255.0

# one-hot encoding
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

# %% [markdown]
# # Compile and Train neural network

# %% [markdown]
# ## CNN Modeling
# Create a convolutional neural network

# %% [markdown]
# ### Goal
#
# Improve the provided basic CNN model and achieve CIFAR-10 **test accuracy ≥ 75%**.

# %% [markdown]
# Modify the network architecture!

# %%
model = tf.keras.models.Sequential([


    tf.keras.layers.Conv2D(64, (3,3), padding='same',
                           activation='relu', input_shape=(32,32,3)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(64, (3,3), padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2,2)),
    tf.keras.layers.Dropout(0.25),


    tf.keras.layers.Conv2D(128, (3,3), padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(128, (3,3), padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2,2)),
    tf.keras.layers.Dropout(0.25),


    tf.keras.layers.Conv2D(256, (3,3), padding='same', activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2,2)),
    tf.keras.layers.Dropout(0.25),

    tf.keras.layers.Flatten(),


    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),

    tf.keras.layers.Dense(10, activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# # Compile and Train neural network

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=8, restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(patience=4, factor=0.5)
]

history = model.fit(
    x_train, y_train,
    epochs=40,
    batch_size=64,
    validation_split=0.1,
    callbacks=callbacks
)
# Out:
# Epoch 1/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 16s 14ms/step - accuracy: 0.7346 - loss: 0.7605 - val_accuracy: 0.8262 - val_loss: 0.5176 - learning_rate: 0.0010
# Epoch 2/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.7462 - loss: 0.7230 - val_accuracy: 0.8074 - val_loss: 0.5749 - learning_rate: 0.0010
# Epoch 3/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7493 - loss: 0.7127 - val_accuracy: 0.8084 - val_loss: 0.5576 - learning_rate: 0.0010
# Epoch 4/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.7522 - loss: 0.7004 - val_accuracy: 0.8150 - val_loss: 0.5476 - learning_rate: 0.0010
# Epoch 5/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.7576 - loss: 0.6886 - val_accuracy: 0.8060 - val_loss: 0.5661 - learning_rate: 0.0010
# Epoch 6/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7825 - loss: 0.6166 - val_accuracy: 0.8254 - val_loss: 0.5073 - learning_rate: 5.0000e-04
# Epoch 7/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.7903 - loss: 0.5966 - val_accuracy: 0.8326 - val_loss: 0.4930 - learning_rate: 5.0000e-04
# Epoch 8/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7930 - loss: 0.5849 - val_accuracy: 0.8300 - val_loss: 0.4975 - learning_rate: 5.0000e-04
# Epoch 9/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8024 - loss: 0.5602 - val_accuracy: 0.8256 - val_loss: 0.5056 - learning_rate: 5.0000e-04
# Epoch 10/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8009 - loss: 0.5679 - val_accuracy: 0.8326 - val_loss: 0.4863 - learning_rate: 5.0000e-04
# Epoch 11/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.8030 - loss: 0.5613 - val_accuracy: 0.8242 - val_loss: 0.5030 - learning_rate: 5.0000e-04
# Epoch 12/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8061 - loss: 0.5495 - val_accuracy: 0.8220 - val_loss: 0.5157 - learning_rate: 5.0000e-04
# Epoch 13/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.8048 - loss: 0.5534 - val_accuracy: 0.8336 - val_loss: 0.4919 - learning_rate: 5.0000e-04
# Epoch 14/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.8143 - loss: 0.5246 - val_accuracy: 0.8312 - val_loss: 0.4983 - learning_rate: 5.0000e-04
# Epoch 15/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8218 - loss: 0.5030 - val_accuracy: 0.8364 - val_loss: 0.4781 - learning_rate: 2.5000e-04
# Epoch 16/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.8293 - loss: 0.4827 - val_accuracy: 0.8366 - val_loss: 0.4708 - learning_rate: 2.5000e-04
# Epoch 17/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8288 - loss: 0.4844 - val_accuracy: 0.8334 - val_loss: 0.4811 - learning_rate: 2.5000e-04
# Epoch 18/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8312 - loss: 0.4799 - val_accuracy: 0.8338 - val_loss: 0.4841 - learning_rate: 2.5000e-04
# Epoch 19/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.8308 - loss: 0.4783 - val_accuracy: 0.8396 - val_loss: 0.4727 - learning_rate: 2.5000e-04
# Epoch 20/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8341 - loss: 0.4695 - val_accuracy: 0.8324 - val_loss: 0.4805 - learning_rate: 2.5000e-04
# Epoch 21/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.8377 - loss: 0.4567 - val_accuracy: 0.8386 - val_loss: 0.4734 - learning_rate: 1.2500e-04
# Epoch 22/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.8412 - loss: 0.4416 - val_accuracy: 0.8384 - val_loss: 0.4674 - learning_rate: 1.2500e-04
# Epoch 23/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8463 - loss: 0.4319 - val_accuracy: 0.8402 - val_loss: 0.4629 - learning_rate: 1.2500e-04
# Epoch 24/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.8421 - loss: 0.4354 - val_accuracy: 0.8396 - val_loss: 0.4732 - learning_rate: 1.2500e-04
# Epoch 25/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8483 - loss: 0.4352 - val_accuracy: 0.8376 - val_loss: 0.4648 - learning_rate: 1.2500e-04
# Epoch 26/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8463 - loss: 0.4349 - val_accuracy: 0.8388 - val_loss: 0.4651 - learning_rate: 1.2500e-04
# Epoch 27/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.8452 - loss: 0.4321 - val_accuracy: 0.8394 - val_loss: 0.4634 - learning_rate: 1.2500e-04
# Epoch 28/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8522 - loss: 0.4138 - val_accuracy: 0.8384 - val_loss: 0.4660 - learning_rate: 6.2500e-05
# Epoch 29/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.8527 - loss: 0.4117 - val_accuracy: 0.8370 - val_loss: 0.4674 - learning_rate: 6.2500e-05
# Epoch 30/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8533 - loss: 0.4139 - val_accuracy: 0.8380 - val_loss: 0.4665 - learning_rate: 6.2500e-05
# Epoch 31/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8474 - loss: 0.4223 - val_accuracy: 0.8442 - val_loss: 0.4619 - learning_rate: 6.2500e-05
# Epoch 32/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.8529 - loss: 0.4161 - val_accuracy: 0.8396 - val_loss: 0.4634 - learning_rate: 6.2500e-05
# Epoch 33/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.8559 - loss: 0.4092 - val_accuracy: 0.8414 - val_loss: 0.4622 - learning_rate: 6.2500e-05
# Epoch 34/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.8554 - loss: 0.4130 - val_accuracy: 0.8372 - val_loss: 0.4701 - learning_rate: 6.2500e-05
# Epoch 35/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.8574 - loss: 0.3996 - val_accuracy: 0.8418 - val_loss: 0.4632 - learning_rate: 6.2500e-05
# Epoch 36/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8539 - loss: 0.4116 - val_accuracy: 0.8416 - val_loss: 0.4589 - learning_rate: 3.1250e-05
# Epoch 37/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.8529 - loss: 0.4158 - val_accuracy: 0.8426 - val_loss: 0.4564 - learning_rate: 3.1250e-05
# Epoch 38/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.8539 - loss: 0.4107 - val_accuracy: 0.8404 - val_loss: 0.4611 - learning_rate: 3.1250e-05
# Epoch 39/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8573 - loss: 0.4032 - val_accuracy: 0.8406 - val_loss: 0.4592 - learning_rate: 3.1250e-05
# Epoch 40/40
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.8561 - loss: 0.3991 - val_accuracy: 0.8426 - val_loss: 0.4615 - learning_rate: 3.1250e-05

# %% [markdown]
# ## Evaluate neural network performance

# %%
model.evaluate(x_test,  y_test, verbose=2)
# Out:
# 313/313 - 2s - 5ms/step - accuracy: 0.8015 - loss: 0.6041
# [0.6041443347930908, 0.8015000224113464]

# %%
prob = model.predict(x_test[0:40], verbose=0)
pred = tf.argmax(prob, axis=1)

fig = plt.figure(figsize=(12, 18))
for i in range(40):
    subplot = fig.add_subplot(8, 5, i + 1)
    subplot.set_xticks([])
    subplot.set_yticks([])
    string = r'$\hat{y}$'
    subplot.set_title(f'$y$:{tf.argmax(y_test[i])}, {string}:{pred[i].numpy()}')
    subplot.imshow(tf.squeeze(x_test[i]))
plt.show()
true_label = tf.argmax(y_test[i]).numpy()
pred_label = pred[i].numpy()
plt.title(f"GT: {true_label}, Pred: {pred_label}")
loss, accuracy = model.evaluate(x_test, y_test, verbose=0)

# %%
loss, accuracy = model.evaluate(x_test, y_test, verbose=0)
print("Test Accuracy:", accuracy)
# Out:
# Test Accuracy: 0.8015000224113464
